# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
file_path = '/Users/kaivalyasatav/Documents/Cognifyz/Level 1/Task 1/Dataset .csv'

# %%
file_path
# Out:
# '/Users/kaivalyasatav/Documents/Cognifyz/Level 1/Task 1/Dataset .csv'

# %%
data = pd.read_csv(file_path)

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
data['Cuisines'].fillna('Unknown',inplace= True) #handled the missing values by putting na as "Unknown"

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
aggregate_rating_distribution = data['Aggregate rating'].value_counts()

# %%
plt.figure(figsize=(10,6))

# %%
data['Aggregate rating'].hist(bins=15, color = 'skyblue', edgecolor = 'black')
# Out:
# <Axes: >

# %%
plt.title("Distribution of Agg Rating", fontsize = 12)
# Out:
# Text(0.5, 1.0, 'Distribution of Agg Rating')

# %%
plt.xlabel("Aggregate Rating", fontsize = 12)
# Out:
# Text(0.5, 0, 'Aggregate Rating')

# %%
plt.ylabel("Frequency", fontsize = 12)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.grid(axis='y',linestyle = "--",alpha = 0.7)

# %%
plt.show()

# %%
class_imbalance = data['Aggregate rating'].value_counts(normalize=True)

# %%
print("Distribution of Aggregate Rating: ")
print(aggregate_rating_distribution)
# Out:
# Distribution of Aggregate Rating:
# Aggregate rating
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: count, dtype: int64

# %%
print("\nClass Imbalance (Normalized): ")
print(class_imbalance)
# Out:
# Class Imbalance (Normalized):
# Aggregate rating
# 0.0    0.224898
# 3.2    0.054654
# 3.1    0.054340
# 3.4    0.052141
# 3.3    0.050571
# 3.5    0.050257
# 3.0    0.049000
# 3.6    0.047953
# 3.7    0.044707
# 3.8    0.041880
# 2.9    0.039891
# 3.9    0.035075
# 2.8    0.032981
# 4.1    0.028688
# 4.0    0.027850
# 2.7    0.026175
# 4.2    0.023139
# 2.6    0.019998
# 4.3    0.018218
# 4.4    0.015077
# 2.5    0.011517
# 4.5    0.009947
# 2.4    0.009109
# 4.6    0.008167
# 4.9    0.006387
# 2.3    0.004921
# 4.7    0.004397
# 2.2    0.002827
# 4.8    0.002618
# 2.1    0.001571
# 2.0    0.000733
# 1.9    0.000209
# 1.8    0.000105
# Name: proportion, dtype: float64
